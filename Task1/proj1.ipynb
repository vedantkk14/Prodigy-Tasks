# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('population_data.csv')
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
new_df = df[['state_name', 'population_male', 'population_female', 'population_total']]

# %%
new_df.head()
# Out:
#        state_name  population_male  population_female  population_total
# 0          PUNJAB            76840              68398            145238
# 1     MAHARASHTRA            58256              54037            112293
# 2  ANDHRA PRADESH            59232              58156            117388
# 3       JHARKHAND            91495              82493            173988
# 4  ANDHRA PRADESH            82743              83794            166537

# %%
total_male = new_df['population_male'].sum()
total_female = new_df['population_female'].sum()
total_population = new_df['population_total'].sum()
print(f"Total population of Male : {total_male}")
print(f"Total population of Female : {total_female}")
print(f"Total population: {total_population}")
# Out:
# Total population of Male : 115532967
# Total population of Female : 105386433
# Total population: 220919400

# %%
type(total_male)
# Out:
# numpy.int64

# %% [markdown]
# ## Male vs. Female Bar chart :-

# %%
from matplotlib.ticker import FuncFormatter

# First subplot
plt.bar(x=['Male', 'Female'],
            height=[total_male, total_female],
            color=['steelblue', 'lightcoral'],
            alpha=0.7,
            edgecolor='black')

formatter = FuncFormatter(lambda x, _: f'{int(x):,}')
plt.gca().yaxis.set_major_formatter(formatter)
plt.xlabel("Total number of Male and Female Population")
plt.ylabel("Population Count")
plt.title("Population Distribution")
plt.grid(axis='y', linestyle='--', alpha=0.7)


plt.tight_layout()
plt.show()
